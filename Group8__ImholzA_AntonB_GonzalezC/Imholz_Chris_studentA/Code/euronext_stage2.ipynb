# %%
import pandas as pd
import numpy as np
import logging

# Load the data file<
file_path = '/home/student/Cloud/Owncloud/SyncVM/CIP/hslu-cip/Group8__ImholzA_AntonB_GonzalezC/Imholz_Chris_studentA/Data/Imholz_Chris_studentA_stage1.csv'
#file_path = '/home/student/Cloud/Owncloud/SyncVM/CIP/hslu-cip/data/raw_data_stage1/Imholz_Chris_studentA_stage1.csv'
data = pd.read_csv(file_path, delimiter=';')


# Display the first few rows of the dataframe and the general information
data.head()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192 entries, 0 to 191
# Data columns (total 29 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Name                                                                 187 non-null    object
#  1   Currency                                                             187 non-null    object
#  2   Market Cap                                                           187 non-null    object
#  3   CDP                                                                  19 non-null     object
#  4   FTSE4Good                                                            4 non-null      object
#  5   MSCI ESG Ratings                                                     4 non-null      object
#  6   Moody's ESG Solution                                                 2 non-null      object
#  7   Sustainalytics                                                       27 non-null     object
#  8   Carbon footprint (total GHG emissions / enterprise value)            119 non-null    object
#  9   Share of women in total workforce                                    157 non-null    object
#  10  Rate of resignation                                                  57 non-null     object
#  11  Type                                                                 187 non-null    object
#  12  Sub type                                                             187 non-null    object
#  13  Market                                                               187 non-null    object
#  14  ISIN Code                                                            187 non-null    object
#  15  Industry                                                             187 non-null    object
#  16  SuperSector                                                          187 non-null    object
#  17  Sector                                                               187 non-null    object
#  18  Subsector                                                            187 non-null    object
#  19  Share of women in management bodies                                  135 non-null    object
#  20  Gender pay gap                                                       59 non-null     object
#  21  Professional equality index                                          28 non-null     object
#  22  Rate of employees with disabilities                                  60 non-null     object
#  23  Average training hours per employee                                  121 non-null    object
#  24  Board gender diversity (female board members / total board members)  168 non-null    object
#  25  Number of female board members                                       168 non-null    object
#  26  Number of board members                                              168 non-null    object
#  27  Total energy consumption                                             140 non-null    object
#  28   Ratio of non-recycled waste                                         0 non-null      float64
# dtypes: float64(1), object(28)
# memory usage: 43.6+ KB

# %%
data
# Out:
#                  Name Currency Market Cap  CDP FTSE4Good MSCI ESG Ratings  \
# 0               ACCOR      EUR     9.656B  NaN       NaN              NaN
# 1         AIR LIQUIDE      EUR    98.258B  NaN       NaN              NaN
# 2           AIRBUS SE      EUR   127.257B  NaN       NaN              NaN
# 3    ARCELORMITTAL SA      EUR    20.331B  NaN       NaN              NaN
# 4                 AXA      EUR    77.141B  NaN       NaN              NaN
# ..                ...      ...        ...  ...       ...              ...
# 187    TELECOM ITALIA      EUR     3.357B  NaN       NaN              NaN
# 188               NaN      NaN        NaN  NaN       NaN              NaN
# 189             TERNA      EUR    14.605B  NaN       NaN              NaN
# 190               NaN      NaN        NaN  NaN       NaN              NaN
# 191            UNIPOL      EUR     5.833B  NaN       NaN              NaN
#
#     Moody's ESG Solution Sustainalytics  \
# 0                    NaN            NaN
# 1                    NaN            NaN
# 2                    NaN            NaN
# 3                    NaN            NaN
# 4                    NaN            NaN
# ..                   ...            ...
# 187                  NaN            NaN
# 188                  NaN            NaN
# 189                  NaN            NaN
# 190                  NaN            NaN
# 191                  NaN            NaN
#
#     Carbon footprint (total GHG emissions / enterprise value)  \
# 0                           535.17 Ton / Million (EUR)
# 1                                                  NaN
# 2                                                  NaN
# 3                        3,373.201 Ton / Million (USD)
# 4                             2.54 Ton / Million (EUR)
# ..                                                 ...
# 187                         124.89 Ton / Million (EUR)
# 188                                                NaN
# 189                       132.1212 Ton / Million (EUR)
# 190                                                NaN
# 191                       476.3635 Ton / Million (EUR)
#
#     Share of women in total workforce  ...  \
# 0                                   %  ...
# 1                                 28%  ...
# 2                                 20%  ...
# 3                                 NaN  ...
# 4                                 NaN  ...
# ..                                ...  ...
# 187                               38%  ...
# 188                               NaN  ...
# 189                            16.08%  ...
# 190                               NaN  ...
# 191                            54.30%  ...
#
#     Share of women in management bodies Gender pay gap  \
# 0                                     %              %
# 1                                   30%            NaN
# 2                                   NaN            NaN
# 3                                15.70%            NaN
# 4                                35.30%            NaN
# ..                                  ...            ...
# 187                                 28%            NaN
# 188                                 NaN            NaN
# 189                              23.70%            19%
# 190                                 NaN            NaN
# 191                              16.23%             9%
#
#     Professional equality index Rate of employees with disabilities  \
# 0                          unit                                   %
# 1                       87 unit                               4.50%
# 2                           NaN                                 NaN
# 3                           NaN                                 NaN
# 4                           NaN                               0.70%
# ..                          ...                                 ...
# 187                         NaN                                  3%
# 188                         NaN                                 NaN
# 189                         NaN                                 NaN
# 190                         NaN                                 NaN
# 191                         NaN                                   %
#
#     Average training hours per employee  \
# 0                                  unit
# 1                               20 unit
# 2                               15 unit
# 3                                   NaN
# 4                                   NaN
# ..                                  ...
# 187                          53.75 unit
# 188                                 NaN
# 189                             36 unit
# 190                                 NaN
# 191                          15.72 unit
#
#     Board gender diversity (female board members / total board members)  \
# 0                                               61.50%
# 1                                               35.70%
# 2                                               33.33%
# 3                                                  30%
# 4                                               56.30%
# ..                                                 ...
# 187                                                40%
# 188                                                NaN
# 189                                             46.15%
# 190                                                NaN
# 191                                                40%
#
#     Number of female board members Number of board members  \
# 0                           8 unit                 13 unit
# 1                           5 unit                 14 unit
# 2                           4 unit                 12 unit
# 3                           3 unit                 10 unit
# 4                           9 unit                 16 unit
# ..                             ...                     ...
# 187                         6 unit                 15 unit
# 188                            NaN                     NaN
# 189                         6 unit                 13 unit
# 190                            NaN                     NaN
# 191                         6 unit                 15 unit
#
#     Total energy consumption  Ratio of non-recycled waste
# 0                 13,712 GWh                          NaN
# 1                        GWh                          NaN
# 2                  3,717 GWh                          NaN
# 3    1,392,000,000 gigajoule                          NaN
# 4                223,638 MWh                          NaN
# ..                       ...                          ...
# 187                2,671 GWh                          NaN
# 188                      NaN                          NaN
# 189      928,277.4 gigajoule                          NaN
# 190                      NaN                          NaN
# 191        530,790 gigajoule                          NaN
#
# [192 rows x 29 columns]

# %%
# Check for columns that are completely empty and drop them
data_not_empty_columns = data.dropna(how='all', axis=1)

# Show the columns removed (if any)
data_not_empty_columns.columns.difference(data.columns)
data=data_not_empty_columns

# Updated DataFrame info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192 entries, 0 to 191
# Data columns (total 28 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Name                                                                 187 non-null    object
#  1   Currency                                                             187 non-null    object
#  2   Market Cap                                                           187 non-null    object
#  3   CDP                                                                  19 non-null     object
#  4   FTSE4Good                                                            4 non-null      object
#  5   MSCI ESG Ratings                                                     4 non-null      object
#  6   Moody's ESG Solution                                                 2 non-null      object
#  7   Sustainalytics                                                       27 non-null     object
#  8   Carbon footprint (total GHG emissions / enterprise value)            119 non-null    object
#  9   Share of women in total workforce                                    157 non-null    object
#  10  Rate of resignation                                                  57 non-null     object
#  11  Type                                                                 187 non-null    object
#  12  Sub type                                                             187 non-null    object
#  13  Market                                                               187 non-null    object
#  14  ISIN Code                                                            187 non-null    object
#  15  Industry                                                             187 non-null    object
#  16  SuperSector                                                          187 non-null    object
#  17  Sector                                                               187 non-null    object
#  18  Subsector                                                            187 non-null    object
#  19  Share of women in management bodies                                  135 non-null    object
#  20  Gender pay gap                                                       59 non-null     object
#  21  Professional equality index                                          28 non-null     object
#  22  Rate of employees with disabilities                                  60 non-null     object
#  23  Average training hours per employee                                  121 non-null    object
#  24  Board gender diversity (female board members / total board members)  168 non-null    object
#  25  Number of female board members                                       168 non-null    object
#  26  Number of board members                                              168 non-null    object
#  27  Total energy consumption                                             140 non-null    object
# dtypes: object(28)
# memory usage: 42.1+ KB

# %%
# Count rows where all elements are NaN
empty_rows_count = data.isna().all(axis=1).sum()
print("Number of completely empty rows:", empty_rows_count)

# Check for rows that are completely empty and drop them
data = data.dropna(how='all', axis=0)
data
# Out:
# Number of completely empty rows: 5
#                    Name Currency Market Cap  CDP FTSE4Good MSCI ESG Ratings  \
# 0                 ACCOR      EUR     9.656B  NaN       NaN              NaN
# 1           AIR LIQUIDE      EUR    98.258B  NaN       NaN              NaN
# 2             AIRBUS SE      EUR   127.257B  NaN       NaN              NaN
# 3      ARCELORMITTAL SA      EUR    20.331B  NaN       NaN              NaN
# 4                   AXA      EUR    77.141B  NaN       NaN              NaN
# ..                  ...      ...        ...  ...       ...              ...
# 185          STELLANTIS      EUR    77.072B  NaN       NaN              NaN
# 186  STMICROELECTRONICS      EUR    34.237B  NaN       NaN              NaN
# 187      TELECOM ITALIA      EUR     3.357B  NaN       NaN              NaN
# 189               TERNA      EUR    14.605B  NaN       NaN              NaN
# 191              UNIPOL      EUR     5.833B  NaN       NaN              NaN
#
#     Moody's ESG Solution Sustainalytics  \
# 0                    NaN            NaN
# 1                    NaN            NaN
# 2                    NaN            NaN
# 3                    NaN            NaN
# 4                    NaN            NaN
# ..                   ...            ...
# 185                  NaN            NaN
# 186                  NaN            NaN
# 187                  NaN            NaN
# 189                  NaN            NaN
# 191                  NaN            NaN
#
#     Carbon footprint (total GHG emissions / enterprise value)  \
# 0                           535.17 Ton / Million (EUR)
# 1                                                  NaN
# 2                                                  NaN
# 3                        3,373.201 Ton / Million (USD)
# 4                             2.54 Ton / Million (EUR)
# ..                                                 ...
# 185                     6,409.5742 Ton / Million (EUR)
# 186                        27.9849 Ton / Million (USD)
# 187                         124.89 Ton / Million (EUR)
# 189                       132.1212 Ton / Million (EUR)
# 191                       476.3635 Ton / Million (EUR)
#
#     Share of women in total workforce  ...  \
# 0                                   %  ...
# 1                                 28%  ...
# 2                                 20%  ...
# 3                                 NaN  ...
# 4                                 NaN  ...
# ..                                ...  ...
# 185                                 %  ...
# 186                                 %  ...
# 187                               38%  ...
# 189                            16.08%  ...
# 191                            54.30%  ...
#
#                                  Subsector  \
# 0              40501025, Hotels and Motels
# 1            55201020, Specialty Chemicals
# 2                      50201010, Aerospace
# 3                 55102010, Iron and Steel
# 4            30302010, Full Line Insurance
# ..                                     ...
# 185                  40101020, Automobiles
# 186               10102010, Semiconductors
# 187  15102015, Telecommunications Services
# 189     65101015, Conventional Electricity
# 191          30302010, Full Line Insurance
#
#     Share of women in management bodies Gender pay gap  \
# 0                                     %              %
# 1                                   30%            NaN
# 2                                   NaN            NaN
# 3                                15.70%            NaN
# 4                                35.30%            NaN
# ..                                  ...            ...
# 185                                   %            NaN
# 186                                   %              %
# 187                                 28%            NaN
# 189                              23.70%            19%
# 191                              16.23%             9%
#
#     Professional equality index Rate of employees with disabilities  \
# 0                          unit                                   %
# 1                       87 unit                               4.50%
# 2                           NaN                                 NaN
# 3                           NaN                                 NaN
# 4                           NaN                               0.70%
# ..                          ...                                 ...
# 185                         NaN                                 NaN
# 186                        unit                                   %
# 187                         NaN                                  3%
# 189                         NaN                                 NaN
# 191                         NaN                                   %
#
#     Average training hours per employee  \
# 0                                  unit
# 1                               20 unit
# 2                               15 unit
# 3                                   NaN
# 4                                   NaN
# ..                                  ...
# 185                                unit
# 186                                unit
# 187                          53.75 unit
# 189                             36 unit
# 191                          15.72 unit
#
#     Board gender diversity (female board members / total board members)  \
# 0                                               61.50%
# 1                                               35.70%
# 2                                               33.33%
# 3                                                  30%
# 4                                               56.30%
# ..                                                 ...
# 185                                             27.27%
# 186                                             44.44%
# 187                                                40%
# 189                                             46.15%
# 191                                                40%
#
#     Number of female board members Number of board members  \
# 0                           8 unit                 13 unit
# 1                           5 unit                 14 unit
# 2                           4 unit                 12 unit
# 3                           3 unit                 10 unit
# 4                           9 unit                 16 unit
# ..                             ...                     ...
# 185                         3 unit                 11 unit
# 186                         4 unit                  9 unit
# 187                         6 unit                 15 unit
# 189                         6 unit                 13 unit
# 191                         6 unit                 15 unit
#
#     Total energy consumption
# 0                 13,712 GWh
# 1                        GWh
# 2                  3,717 GWh
# 3    1,392,000,000 gigajoule
# 4                223,638 MWh
# ..                       ...
# 185           15,494,891 MWh
# 186      10,363.96 terajoule
# 187                2,671 GWh
# 189      928,277.4 gigajoule
# 191        530,790 gigajoule
#
# [187 rows x 28 columns]

# %%
# Helper function to convert Market Cap to numeric
# Beispiel-Wechselkurse zu USD: Google 18. Apr., 13:08 UTC
exchange_rates = {
'EUR': 1.07,
'GBP': 1.25,
'NOK': 0.091,
'USD': 1
}

def expand_number(value):
    if pd.isna(value):
        return np.nan
    value = value.strip().upper()
    if value.endswith('B'):
        value =  float(value[:-1]) * 1e9  # Convert billions to a numeric value
    elif value.endswith('M'):
        value =  float(value[:-1]) * 1e6  # Convert millions to a numeric value
    elif value.endswith('K'):
        value =  float(value[:-1]) * 1e3  # Convert thousands to a numeric value
    else:
        value = float(value)  # Handle numeric-only strings as is
    return round(value,3)

def convert_to_usd(currency, amount):
    if pd.isna(amount):
        return np.nan
    return amount * exchange_rates[currency]

def process_market_cap(row):
    # Erweitere den Betrag zu einer vollständigen Zahl
    full_amount = expand_number(row['Market Cap'])
    # Wandle die Währung in USD um
    amount_in_usd = convert_to_usd(row['Currency'], full_amount)
    return amount_in_usd

# Lade den DataFrame, hier durch eine CSV-Datei ersetzt
# data = pd.read_csv('path_to_your_csv.csv')

# Annahme: 'data' ist ein DataFrame mit den Spalten 'Currency' und 'Market Cap'
# Anwenden der Funktion
data['Market Cap in USD'] = data.apply(process_market_cap, axis=1)
data = data.drop('Market Cap',axis='columns')
# Out:
# /tmp/ipykernel_2560/3642019202.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Market Cap in USD'] = data.apply(process_market_cap, axis=1)

# %%
def parse_and_convert_tons_currency(value):
    # Prüft auf NaN Werte
    if pd.isna(value) or value == '':
        return None
    
    parts = value.split(' ')
    
    if len(parts) < 5:
        return None

    # Extrahiert den Betrag, die Einheit und die Währung
    if parts[0].replace(',', '') == '':
        return None
    else:
        amount = float(parts[0].replace(',', ''))
    
    unit = parts[2]
    currency = parts[4].strip('()')

    # Konvertiert Tausend in Millionen, falls nötig
    if unit == 'Thousand':
        amount /= 1000

    # Wandelt den Betrag in USD um, falls er nicht bereits in USD ist
    if currency != 'USD':
        amount *= round(float(exchange_rates.get(currency,1)),3)

    return amount

# Anwendung der Funktion
data['Carbon footprint (total GHG emissions / enterprise value)' + '_in_USD'] = data['Carbon footprint (total GHG emissions / enterprise value)'].apply(parse_and_convert_tons_currency)
data = data.drop('Carbon footprint (total GHG emissions / enterprise value)',axis='columns')
data
# Out:
#                    Name Currency  CDP FTSE4Good MSCI ESG Ratings  \
# 0                 ACCOR      EUR  NaN       NaN              NaN
# 1           AIR LIQUIDE      EUR  NaN       NaN              NaN
# 2             AIRBUS SE      EUR  NaN       NaN              NaN
# 3      ARCELORMITTAL SA      EUR  NaN       NaN              NaN
# 4                   AXA      EUR  NaN       NaN              NaN
# ..                  ...      ...  ...       ...              ...
# 185          STELLANTIS      EUR  NaN       NaN              NaN
# 186  STMICROELECTRONICS      EUR  NaN       NaN              NaN
# 187      TELECOM ITALIA      EUR  NaN       NaN              NaN
# 189               TERNA      EUR  NaN       NaN              NaN
# 191              UNIPOL      EUR  NaN       NaN              NaN
#
#     Moody's ESG Solution Sustainalytics Share of women in total workforce  \
# 0                    NaN            NaN                                 %
# 1                    NaN            NaN                               28%
# 2                    NaN            NaN                               20%
# 3                    NaN            NaN                               NaN
# 4                    NaN            NaN                               NaN
# ..                   ...            ...                               ...
# 185                  NaN            NaN                                 %
# 186                  NaN            NaN                                 %
# 187                  NaN            NaN                               38%
# 189                  NaN            NaN                            16.08%
# 191                  NaN            NaN                            54.30%
#
#     Rate of resignation   Type  ... Gender pay gap  \
# 0                     %  Stock  ...              %
# 1                 8.60%  Stock  ...            NaN
# 2                   NaN  Stock  ...            NaN
# 3                   NaN  Stock  ...            NaN
# 4                   10%  Stock  ...            NaN
# ..                  ...    ...  ...            ...
# 185                   %  Stock  ...            NaN
# 186                   %  Stock  ...              %
# 187                 NaN  Stock  ...            NaN
# 189               1.80%  Stock  ...            19%
# 191               2.70%  Stock  ...             9%
#
#     Professional equality index Rate of employees with disabilities  \
# 0                          unit                                   %
# 1                       87 unit                               4.50%
# 2                           NaN                                 NaN
# 3                           NaN                                 NaN
# 4                           NaN                               0.70%
# ..                          ...                                 ...
# 185                         NaN                                 NaN
# 186                        unit                                   %
# 187                         NaN                                  3%
# 189                         NaN                                 NaN
# 191                         NaN                                   %
#
#     Average training hours per employee  \
# 0                                  unit
# 1                               20 unit
# 2                               15 unit
# 3                                   NaN
# 4                                   NaN
# ..                                  ...
# 185                                unit
# 186                                unit
# 187                          53.75 unit
# 189                             36 unit
# 191                          15.72 unit
#
#     Board gender diversity (female board members / total board members)  \
# 0                                               61.50%
# 1                                               35.70%
# 2                                               33.33%
# 3                                                  30%
# 4                                               56.30%
# ..                                                 ...
# 185                                             27.27%
# 186                                             44.44%
# 187                                                40%
# 189                                             46.15%
# 191                                                40%
#
#     Number of female board members Number of board members  \
# 0                           8 unit                 13 unit
# 1                           5 unit                 14 unit
# 2                           4 unit                 12 unit
# 3                           3 unit                 10 unit
# 4                           9 unit                 16 unit
# ..                             ...                     ...
# 185                         3 unit                 11 unit
# 186                         4 unit                  9 unit
# 187                         6 unit                 15 unit
# 189                         6 unit                 13 unit
# 191                         6 unit                 15 unit
#
#     Total energy consumption Market Cap in USD  \
# 0                 13,712 GWh      1.033192e+10
# 1                        GWh      1.051361e+11
# 2                  3,717 GWh      1.361650e+11
# 3    1,392,000,000 gigajoule      2.175417e+10
# 4                223,638 MWh      8.254087e+10
# ..                       ...               ...
# 185           15,494,891 MWh      8.246704e+10
# 186      10,363.96 terajoule      3.663359e+10
# 187                2,671 GWh      3.591990e+09
# 189      928,277.4 gigajoule      1.562735e+10
# 191        530,790 gigajoule      6.241310e+09
#
#     Carbon footprint (total GHG emissions / enterprise value)_in_USD
# 0                                           572.631900
# 1                                                  NaN
# 2                                                  NaN
# 3                                          3373.201000
# 4                                             2.717800
# ..                                                 ...
# 185                                        6858.244394
# 186                                          27.984900
# 187                                         133.632300
# 189                                         141.369684
# 191                                         509.708945
#
# [187 rows x 28 columns]

# %%
# Helper function to convert percentage strings to floats
def convert_percentage(value):
    if pd.isna(value) or value.strip('% ') == '':
        return np.nan
    return round(float(value.strip('% ')) / 100,3)

def unit_strip(value):
    if pd.isna(value) or value.strip('unit') == '':
        return np.nan
    elif value.replace('unit', '') == " ":
        return np.nan
    return float(value.replace('unit', ''))

import re
def convert_to_mwh(value):
    conversion_factors = {
    'GWh': 1000,
    'terajoule': 277.778,
    'gigajoule': 0.277778,
    'MWh': 1
    }
    match = re.search(r'([\d,]+(?:\.\d+)?)\s*(GWh|MWh|terajoule|gigajoule)', str(value).replace(',', ''))
    if match:
        # Convert string value to float
        value = float(match.group(1).replace(',', ''))
        unit = match.group(2)
        return round(value * conversion_factors[unit],3) # Convert the value to MWh

# Apply conversions
data['Share of women in total workforce in %'] = data['Share of women in total workforce'].apply(convert_percentage)
data = data.drop("Share of women in total workforce",axis='columns')
data['Share of women in management bodies in %'] = data['Share of women in management bodies'].apply(convert_percentage)
data = data.drop('Share of women in management bodies',axis='columns')
data['Gender pay gap in %'] = data['Gender pay gap'].apply(convert_percentage)
data = data.drop('Gender pay gap',axis='columns')
data['Rate of employees with disabilities in %'] = data['Rate of employees with disabilities'].apply(convert_percentage)
data = data.drop('Rate of employees with disabilities',axis='columns')
data['Board gender diversity (female board members / total board members) in %'] = data['Board gender diversity (female board members / total board members)'].apply(convert_percentage)
data = data.drop('Board gender diversity (female board members / total board members)',axis='columns')
data['Professional equality index'] = data['Professional equality index'].apply(unit_strip)
data['Number of female board members'] = data['Number of female board members'].apply(unit_strip)
data['Number of board members'] = data['Number of board members'].apply(unit_strip)
data['Average training hours per employee'] = data['Average training hours per employee'].apply(unit_strip)
data['Total energy consumption in mwh'] = data['Total energy consumption'].apply(convert_to_mwh)
data = data.drop('Total energy consumption', axis='columns')
data['Rate of resignation in %'] = data['Rate of resignation'].apply(convert_percentage)
data = data.drop('Rate of resignation', axis='columns')
data

# Transformed data
data.head()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 187 entries, 0 to 191
# Data columns (total 28 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   Name                                                                      187 non-null    object
#  1   Currency                                                                  187 non-null    object
#  2   CDP                                                                       19 non-null     object
#  3   FTSE4Good                                                                 4 non-null      object
#  4   MSCI ESG Ratings                                                          4 non-null      object
#  5   Moody's ESG Solution                                                      2 non-null      object
#  6   Sustainalytics                                                            27 non-null     object
#  7   Type                                                                      187 non-null    object
#  8   Sub type                                                                  187 non-null    object
#  9   Market                                                                    187 non-null    object
#  10  ISIN Code                                                                 187 non-null    object
#  11  Industry                                                                  187 non-null    object
#  12  SuperSector                                                               187 non-null    object
#  13  Sector                                                                    187 non-null    object
#  14  Subsector                                                                 187 non-null    object
#  15  Professional equality index                                               21 non-null     float64
#  16  Average training hours per employee                                       106 non-null    float64
#  17  Number of female board members                                            168 non-null    float64
#  18  Number of board members                                                   168 non-null    float64
#  19  Market Cap in USD                                                         187 non-null    float64
#  20  Carbon footprint (total GHG emissions / enterprise value)_in_USD          115 non-null    float64
#  21  Share of women in total workforce in %                                    144 non-null    float64
#  22  Share of women in management bodies in %                                  125 non-null    float64
#  23  Gender pay gap in %                                                       47 non-null     float64
#  24  Rate of employees with disabilities in %                                  50 non-null     float64
#  25  Board gender diversity (female board members / total board members) in %  168 non-null    float64
#  26  Total energy consumption in mwh                                           124 non-null    float64
#  27  Rate of resignation in %                                                  51 non-null     float64
# dtypes: float64(13), object(15)
# memory usage: 42.4+ KB

# %%
data
# Out:
#                    Name Currency  CDP FTSE4Good MSCI ESG Ratings  \
# 0                 ACCOR      EUR  NaN       NaN              NaN
# 1           AIR LIQUIDE      EUR  NaN       NaN              NaN
# 2             AIRBUS SE      EUR  NaN       NaN              NaN
# 3      ARCELORMITTAL SA      EUR  NaN       NaN              NaN
# 4                   AXA      EUR  NaN       NaN              NaN
# ..                  ...      ...  ...       ...              ...
# 185          STELLANTIS      EUR  NaN       NaN              NaN
# 186  STMICROELECTRONICS      EUR  NaN       NaN              NaN
# 187      TELECOM ITALIA      EUR  NaN       NaN              NaN
# 189               TERNA      EUR  NaN       NaN              NaN
# 191              UNIPOL      EUR  NaN       NaN              NaN
#
#     Moody's ESG Solution Sustainalytics   Type         Sub type  \
# 0                    NaN            NaN  Stock  Ordinary Shares
# 1                    NaN            NaN  Stock  Ordinary Shares
# 2                    NaN            NaN  Stock  Ordinary Shares
# 3                    NaN            NaN  Stock  Ordinary Shares
# 4                    NaN            NaN  Stock  Ordinary Shares
# ..                   ...            ...    ...              ...
# 185                  NaN            NaN  Stock  Ordinary Shares
# 186                  NaN            NaN  Stock  Ordinary Shares
# 187                  NaN            NaN  Stock  Ordinary Shares
# 189                  NaN            NaN  Stock  Ordinary Shares
# 191                  NaN            NaN  Stock  Ordinary Shares
#
#                  Market  ... Number of board members Market Cap in USD  \
# 0        Euronext Paris  ...                    13.0      1.033192e+10
# 1        Euronext Paris  ...                    14.0      1.051361e+11
# 2        Euronext Paris  ...                    12.0      1.361650e+11
# 3    Euronext Amsterdam  ...                    10.0      2.175417e+10
# 4        Euronext Paris  ...                    16.0      8.254087e+10
# ..                  ...  ...                     ...               ...
# 185      Euronext Milan  ...                    11.0      8.246704e+10
# 186      Euronext Milan  ...                     9.0      3.663359e+10
# 187      Euronext Milan  ...                    15.0      3.591990e+09
# 189      Euronext Milan  ...                    13.0      1.562735e+10
# 191      Euronext Milan  ...                    15.0      6.241310e+09
#
#     Carbon footprint (total GHG emissions / enterprise value)_in_USD  \
# 0                                           572.631900
# 1                                                  NaN
# 2                                                  NaN
# 3                                          3373.201000
# 4                                             2.717800
# ..                                                 ...
# 185                                        6858.244394
# 186                                          27.984900
# 187                                         133.632300
# 189                                         141.369684
# 191                                         509.708945
#
#     Share of women in total workforce in %  \
# 0                                      NaN
# 1                                    0.280
# 2                                    0.200
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 185                                    NaN
# 186                                    NaN
# 187                                  0.380
# 189                                  0.161
# 191                                  0.543
#
#     Share of women in management bodies in %  Gender pay gap in %  \
# 0                                        NaN                  NaN
# 1                                      0.300                  NaN
# 2                                        NaN                  NaN
# 3                                      0.157                  NaN
# 4                                      0.353                  NaN
# ..                                       ...                  ...
# 185                                      NaN                  NaN
# 186                                      NaN                  NaN
# 187                                    0.280                  NaN
# 189                                    0.237                 0.19
# 191                                    0.162                 0.09
#
#      Rate of employees with disabilities in %  \
# 0                                         NaN
# 1                                       0.045
# 2                                         NaN
# 3                                         NaN
# 4                                       0.007
# ..                                        ...
# 185                                       NaN
# 186                                       NaN
# 187                                     0.030
# 189                                       NaN
# 191                                       NaN
#
#      Board gender diversity (female board members / total board members) in %  \
# 0                                                0.615
# 1                                                0.357
# 2                                                0.333
# 3                                                0.300
# 4                                                0.563
# ..                                                 ...
# 185                                              0.273
# 186                                              0.444
# 187                                              0.400
# 189                                              0.461
# 191                                              0.400
#
#      Total energy consumption in mwh  Rate of resignation in %
# 0                       1.371200e+07                       NaN
# 1                                NaN                     0.086
# 2                       3.717000e+06                       NaN
# 3                       3.866670e+08                       NaN
# 4                       2.236380e+05                     0.100
# ..                               ...                       ...
# 185                     1.549489e+07                       NaN
# 186                     2.878880e+06                       NaN
# 187                     2.671000e+06                       NaN
# 189                     2.578550e+05                     0.018
# 191                     1.474418e+05                     0.027
#
# [187 rows x 28 columns]

# %%
# Calculate the percentage of missing values per column
missing_data = data.isnull().mean() * 100.00

# Display the percentage of missing data per column
missing_data_sorted = missing_data.sort_values(ascending=False)
missing_data_sorted
# Out:
# Moody's ESG Solution                                                        98.930481
# FTSE4Good                                                                   97.860963
# MSCI ESG Ratings                                                            97.860963
# CDP                                                                         89.839572
# Professional equality index                                                 88.770053
# Sustainalytics                                                              85.561497
# Gender pay gap in %                                                         74.866310
# Rate of employees with disabilities in %                                    73.262032
# Rate of resignation in %                                                    72.727273
# Average training hours per employee                                         43.315508
# Carbon footprint (total GHG emissions / enterprise value)_in_USD            38.502674
# Total energy consumption in mwh                                             33.689840
# Share of women in management bodies in %                                    33.155080
# Share of women in total workforce in %                                      22.994652
# Number of board members                                                     10.160428
# Board gender diversity (female board members / total board members) in %    10.160428
# Number of female board members                                              10.160428
# Market Cap in USD                                                            0.000000
# Name                                                                         0.000000
# Currency                                                                     0.000000
# Sector                                                                       0.000000
# SuperSector                                                                  0.000000
# Industry                                                                     0.000000
# ISIN Code                                                                    0.000000
# Market                                                                       0.000000
# Sub type                                                                     0.000000
# Type                                                                         0.000000
# Subsector                                                                    0.000000
# dtype: float64

# %%
# Finden der Spalten, bei denen der Prozentsatz der fehlenden Daten größer als 80% ist
columns_to_drop = missing_data[missing_data > 80].index
# Löschen dieser Spalten aus dem DataFrame
data.drop(columns=columns_to_drop, inplace=True)
data
# Out:
#                    Name Currency   Type         Sub type              Market  \
# 0                 ACCOR      EUR  Stock  Ordinary Shares      Euronext Paris
# 1           AIR LIQUIDE      EUR  Stock  Ordinary Shares      Euronext Paris
# 2             AIRBUS SE      EUR  Stock  Ordinary Shares      Euronext Paris
# 3      ARCELORMITTAL SA      EUR  Stock  Ordinary Shares  Euronext Amsterdam
# 4                   AXA      EUR  Stock  Ordinary Shares      Euronext Paris
# ..                  ...      ...    ...              ...                 ...
# 185          STELLANTIS      EUR  Stock  Ordinary Shares      Euronext Milan
# 186  STMICROELECTRONICS      EUR  Stock  Ordinary Shares      Euronext Milan
# 187      TELECOM ITALIA      EUR  Stock  Ordinary Shares      Euronext Milan
# 189               TERNA      EUR  Stock  Ordinary Shares      Euronext Milan
# 191              UNIPOL      EUR  Stock  Ordinary Shares      Euronext Milan
#
#         ISIN Code                    Industry  \
# 0    FR0000120404  40, Consumer Discretionary
# 1    FR0000120073         55, Basic Materials
# 2    NL0000235190             50, Industrials
# 3    LU1598757687         55, Basic Materials
# 4    FR0000120628              30, Financials
# ..            ...                         ...
# 185  NL00150001Q9  40, Consumer Discretionary
# 186  NL0000226223              10, Technology
# 187  IT0003497168      15, Telecommunications
# 189  IT0003242622               65, Utilities
# 191  IT0004810054              30, Financials
#
#                              SuperSector  \
# 0               4050, Travel and Leisure
# 1                        5520, Chemicals
# 2    5020, Industrial Goods and Services
# 3                  5510, Basic Resources
# 4                        3030, Insurance
# ..                                   ...
# 185          4010, Automobiles and Parts
# 186                     1010, Technology
# 187             1510, Telecommunications
# 189                      6510, Utilities
# 191                      3030, Insurance
#
#                                            Sector  \
# 0                      405010, Travel and Leisure
# 1                               552010, Chemicals
# 2                   502010, Aerospace and Defense
# 3            551020, Industrial Metals and Mining
# 4                      303020, Non-life Insurance
# ..                                            ...
# 185                 401010, Automobiles and Parts
# 186     101020, Technology Hardware and Equipment
# 187  151020, Telecommunications Service Providers
# 189                           651010, Electricity
# 191                    303020, Non-life Insurance
#
#                                  Subsector  ...  Number of board members  \
# 0              40501025, Hotels and Motels  ...                     13.0
# 1            55201020, Specialty Chemicals  ...                     14.0
# 2                      50201010, Aerospace  ...                     12.0
# 3                 55102010, Iron and Steel  ...                     10.0
# 4            30302010, Full Line Insurance  ...                     16.0
# ..                                     ...  ...                      ...
# 185                  40101020, Automobiles  ...                     11.0
# 186               10102010, Semiconductors  ...                      9.0
# 187  15102015, Telecommunications Services  ...                     15.0
# 189     65101015, Conventional Electricity  ...                     13.0
# 191          30302010, Full Line Insurance  ...                     15.0
#
#      Market Cap in USD  \
# 0         1.033192e+10
# 1         1.051361e+11
# 2         1.361650e+11
# 3         2.175417e+10
# 4         8.254087e+10
# ..                 ...
# 185       8.246704e+10
# 186       3.663359e+10
# 187       3.591990e+09
# 189       1.562735e+10
# 191       6.241310e+09
#
#      Carbon footprint (total GHG emissions / enterprise value)_in_USD  \
# 0                                           572.631900
# 1                                                  NaN
# 2                                                  NaN
# 3                                          3373.201000
# 4                                             2.717800
# ..                                                 ...
# 185                                        6858.244394
# 186                                          27.984900
# 187                                         133.632300
# 189                                         141.369684
# 191                                         509.708945
#
#      Share of women in total workforce in %  \
# 0                                       NaN
# 1                                     0.280
# 2                                     0.200
# 3                                       NaN
# 4                                       NaN
# ..                                      ...
# 185                                     NaN
# 186                                     NaN
# 187                                   0.380
# 189                                   0.161
# 191                                   0.543
#
#      Share of women in management bodies in %  Gender pay gap in %  \
# 0                                         NaN                  NaN
# 1                                       0.300                  NaN
# 2                                         NaN                  NaN
# 3                                       0.157                  NaN
# 4                                       0.353                  NaN
# ..                                        ...                  ...
# 185                                       NaN                  NaN
# 186                                       NaN                  NaN
# 187                                     0.280                  NaN
# 189                                     0.237                 0.19
# 191                                     0.162                 0.09
#
#      Rate of employees with disabilities in %  \
# 0                                         NaN
# 1                                       0.045
# 2                                         NaN
# 3                                         NaN
# 4                                       0.007
# ..                                        ...
# 185                                       NaN
# 186                                       NaN
# 187                                     0.030
# 189                                       NaN
# 191                                       NaN
#
#      Board gender diversity (female board members / total board members) in %  \
# 0                                                0.615
# 1                                                0.357
# 2                                                0.333
# 3                                                0.300
# 4                                                0.563
# ..                                                 ...
# 185                                              0.273
# 186                                              0.444
# 187                                              0.400
# 189                                              0.461
# 191                                              0.400
#
#      Total energy consumption in mwh  Rate of resignation in %
# 0                       1.371200e+07                       NaN
# 1                                NaN                     0.086
# 2                       3.717000e+06                       NaN
# 3                       3.866670e+08                       NaN
# 4                       2.236380e+05                     0.100
# ..                               ...                       ...
# 185                     1.549489e+07                       NaN
# 186                     2.878880e+06                       NaN
# 187                     2.671000e+06                       NaN
# 189                     2.578550e+05                     0.018
# 191                     1.474418e+05                     0.027
#
# [187 rows x 22 columns]

# %%
columns_to_drop
# Out:
# Index(['CDP', 'FTSE4Good', 'MSCI ESG Ratings', 'Moody's ESG Solution',
#        'Sustainalytics', 'Professional equality index'],
#       dtype='object')

# %%
data.columns
# Out:
# Index(['Name', 'Currency', 'Type', 'Sub type', 'Market', 'ISIN Code',
#        'Industry', 'SuperSector', 'Sector', 'Subsector',
#        'Average training hours per employee', 'Number of female board members',
#        'Number of board members', 'Market Cap in USD',
#        'Carbon footprint (total GHG emissions / enterprise value)_in_USD',
#        'Share of women in total workforce in %',
#        'Share of women in management bodies in %', 'Gender pay gap in %',
#        'Rate of employees with disabilities in %',
#        'Board gender diversity (female board members / total board members) in %',
#        'Total energy consumption in mwh', 'Rate of resignation in %'],
#       dtype='object')

# %%
#Save DataFrame to a CSV file with semicolon as the delimiter with the required _stage2.csv ending form project
data.to_csv('/home/student/Cloud/Owncloud/SyncVM/CIP/hslu-cip/Group8__ImholzA_AntonB_GonzalezC/Imholz_Chris_studentA/Data/Imholz_Chris_studentA_stage3.csv', sep=';', index=False)
# data.to_csv('/home/student/Cloud/Owncloud/SyncVM/CIP/hslu-cip/data/clean_data_stage3/Imholz_Chris_studentA_stage3.csv', sep=';', index=False)

# %%
# Tabel erstellen 
CREATE TABLE tbl_financial_euronext_data (
    id INT AUTO_INCREMENT PRIMARY KEY,
    name VARCHAR(255),
    currency VARCHAR(255),
    market_cap_in_USD VARCHAR(255),
    carbon_footprint_total_GHG_emissions_per_enterprise_value VARCHAR(255),
    security_type VARCHAR(255),
    security_type_subtype VARCHAR(255),
    market VARCHAR(255),
    isin VARCHAR(20),
    industry VARCHAR(255),
    super_sector VARCHAR(255),
    sector VARCHAR(255),
    subsector VARCHAR(255),
    average_training_hours_per_employee VARCHAR(255),
    number_of_female_board_members VARCHAR(255),
    number_of_board_members VARCHAR(255),
    share_of_woman_in_total_workforce_in_percent VARCHAR(255),
    share_of_woman_in_management_bodies_in_percent VARCHAR(255),
    gender_pay_gap_in_percent VARCHAR(255),
    rate_of_employees_with_disabilities_in_percent VARCHAR(255),
    board_gender_diversity_in_percent VARCHAR(255),
    total_energy_consumption_in_mwh VARCHAR(255),
    rate_of_resignation_in_percent VARCHAR(255),
);
# Out:
#   Cell In[74], line 2
#     CREATE TABLE tbl_financial_euronext_data (
#            ^
# SyntaxError: invalid syntax

# %%
data.count
# Out:
# <bound method DataFrame.count of                    Name Currency   Type         Sub type              Market  \
# 0                 ACCOR      EUR  Stock  Ordinary Shares      Euronext Paris
# 1           AIR LIQUIDE      EUR  Stock  Ordinary Shares      Euronext Paris
# 2             AIRBUS SE      EUR  Stock  Ordinary Shares      Euronext Paris
# 3      ARCELORMITTAL SA      EUR  Stock  Ordinary Shares  Euronext Amsterdam
# 4                   AXA      EUR  Stock  Ordinary Shares      Euronext Paris
# ..                  ...      ...    ...              ...                 ...
# 185          STELLANTIS      EUR  Stock  Ordinary Shares      Euronext Milan
# 186  STMICROELECTRONICS      EUR  Stock  Ordinary Shares      Euronext Milan
# 187      TELECOM ITALIA      EUR  Stock  Ordinary Shares      Euronext Milan
# 189               TERNA      EUR  Stock  Ordinary Shares      Euronext Milan
# 191              UNIPOL      EUR  Stock  Ordinary Shares      Euronext Milan
#
#         ISIN Code                    Industry  \
# 0    FR0000120404  40, Consumer Discretionary
# 1    FR0000120073         55, Basic Materials
# 2    NL0000235190             50, Industrials
# 3    LU1598757687         55, Basic Materials
# 4    FR0000120628              30, Financials
# ..            ...                         ...
# 185  NL00150001Q9  40, Consumer Discretionary
# 186  NL0000226223              10, Technology
# 187  IT0003497168      15, Telecommunications
# 189  IT0003242622               65, Utilities
# 191  IT0004810054              30, Financials
#
#                              SuperSector  \
# 0               4050, Travel and Leisure
# 1                        5520, Chemicals
# 2    5020, Industrial Goods and Services
# 3                  5510, Basic Resources
# 4                        3030, Insurance
# ..                                   ...
# 185          4010, Automobiles and Parts
# 186                     1010, Technology
# 187             1510, Telecommunications
# 189                      6510, Utilities
# 191                      3030, Insurance
#
#                                            Sector  \
# 0                      405010, Travel and Leisure
# 1                               552010, Chemicals
# 2                   502010, Aerospace and Defense
# 3            551020, Industrial Metals and Mining
# 4                      303020, Non-life Insurance
# ..                                            ...
# 185                 401010, Automobiles and Parts
# 186     101020, Technology Hardware and Equipment
# 187  151020, Telecommunications Service Providers
# 189                           651010, Electricity
# 191                    303020, Non-life Insurance
#
#                                  Subsector  ...  Number of board members  \
# 0              40501025, Hotels and Motels  ...                     13.0
# 1            55201020, Specialty Chemicals  ...                     14.0
# 2                      50201010, Aerospace  ...                     12.0
# 3                 55102010, Iron and Steel  ...                     10.0
# 4            30302010, Full Line Insurance  ...                     16.0
# ..                                     ...  ...                      ...
# 185                  40101020, Automobiles  ...                     11.0
# 186               10102010, Semiconductors  ...                      9.0
# 187  15102015, Telecommunications Services  ...                     15.0
# 189     65101015, Conventional Electricity  ...                     13.0
# 191          30302010, Full Line Insurance  ...                     15.0
#
#      Market Cap in USD  \
# 0         1.033192e+10
# 1         1.051361e+11
# 2         1.361650e+11
# 3         2.175417e+10
# 4         8.254087e+10
# ..                 ...
# 185       8.246704e+10
# 186       3.663359e+10
# 187       3.591990e+09
# 189       1.562735e+10
# 191       6.241310e+09
#
#      Carbon footprint (total GHG emissions / enterprise value)_in_USD  \
# 0                                           572.631900
# 1                                                  NaN
# 2                                                  NaN
# 3                                          3373.201000
# 4                                             2.717800
# ..                                                 ...
# 185                                        6858.244394
# 186                                          27.984900
# 187                                         133.632300
# 189                                         141.369684
# 191                                         509.708945
#
#      Share of women in total workforce in %  \
# 0                                       NaN
# 1                                     0.280
# 2                                     0.200
# 3                                       NaN
# 4                                       NaN
# ..                                      ...
# 185                                     NaN
# 186                                     NaN
# 187                                   0.380
# 189                                   0.161
# 191                                   0.543
#
#      Share of women in management bodies in %  Gender pay gap in %  \
# 0                                         NaN                  NaN
# 1                                       0.300                  NaN
# 2                                         NaN                  NaN
# 3                                       0.157                  NaN
# 4                                       0.353                  NaN
# ..                                        ...                  ...
# 185                                       NaN                  NaN
# 186                                       NaN                  NaN
# 187                                     0.280                  NaN
# 189                                     0.237                 0.19
# 191                                     0.162                 0.09
#
#      Rate of employees with disabilities in %  \
# 0                                         NaN
# 1                                       0.045
# 2                                         NaN
# 3                                         NaN
# 4                                       0.007
# ..                                        ...
# 185                                       NaN
# 186                                       NaN
# 187                                     0.030
# 189                                       NaN
# 191                                       NaN
#
#      Board gender diversity (female board members / total board members) in %  \
# 0                                                0.615
# 1                                                0.357
# 2                                                0.333
# 3                                                0.300
# 4                                                0.563
# ..                                                 ...
# 185                                              0.273
# 186                                              0.444
# 187                                              0.400
# 189                                              0.461
# 191                                              0.400
#
#      Total energy consumption in mwh  Rate of resignation in %
# 0                       1.371200e+07                       NaN
# 1                                NaN                     0.086
# 2                       3.717000e+06                       NaN
# 3                       3.866670e+08                       NaN
# 4                       2.236380e+05                     0.100
# ..                               ...                       ...
# 185                     1.549489e+07                       NaN
# 186                     2.878880e+06                       NaN
# 187                     2.671000e+06                       NaN
# 189                     2.578550e+05                     0.018
# 191                     1.474418e+05                     0.027
#
# [187 rows x 22 columns]>

# %%
import mariadb
import sys
import pandas as pd


data = data.where(pd.notnull(data), None)
# Verbindung zur Datenbank herstellen
try:
    conn = mariadb.connect(
        user="cip_user",
        password="cip_pw",
        host="127.0.0.1",
        port=3306,
        database="CIP"
    )
except mariadb.Error as e:
    print(f"Error connecting to MariaDB Platform: {e}")
    sys.exit(1)

conn.autocommit = False
cur = conn.cursor()

# Daten in die Datenbank einfügen
errors = []
for index, row in data.iterrows():
    query = """
    INSERT INTO tbl_financial_euronext_data
    (name, currency, market_cap_in_USD, carbon_footprint_total_GHG_emissions_per_enterprise_value, security_type, security_type_subtype, market, isin, industry, super_sector, sector, subsector, average_training_hours_per_employee, number_of_female_board_members, number_of_board_members, share_of_woman_in_total_workforce_in_percent, share_of_woman_in_management_bodies_in_percent, gender_pay_gap_in_percent, rate_of_employees_with_disabilities_in_percent, board_gender_diversity_in_percent, total_energy_consumption_in_mwh, rate_of_resignation_in_percent) 
    VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
    """
    try:
        cur.execute(query, (
            row['Name'],
            row['Currency'],
            row['Market Cap in USD'],
            row['Carbon footprint (total GHG emissions / enterprise value)_in_USD'],
            row['Type'],
            row['Sub type'],
            row['Market'],
            row['ISIN Code'],
            row['Industry'],
            row['SuperSector'],
            row['Sector'],
            row['Subsector'],
            row['Average training hours per employee'],
            row['Number of female board members'],
            row['Number of board members'],
            row['Share of women in total workforce in %'],
            row['Share of women in management bodies in %'],
            row['Gender pay gap in %'],
            row['Rate of employees with disabilities in %'],
            row['Board gender diversity (female board members / total board members) in %'],
            row['Total energy consumption in mwh'],
            row['Rate of resignation in %']
        ))
    except mariadb.Error as e:
        errors.append(f"Error: {e} at index {index}")
        continue

# Änderungen bestätigen und Verbindung schließen
conn.commit()
conn.close()

# Fehler und Erfolgsmeldung ausgeben
if errors:
    print(f"Es gab {len(errors)} Fehler beim Einfügen der Daten.")
for error in errors:
    print(error)
print("Data insertion complete.")
# Out:
# Es gab 180 Fehler beim Einfügen der Daten.
# Error: Unknown column 'nan' in 'field list' at index 0
# Error: Unknown column 'nan' in 'field list' at index 1
# Error: Unknown column 'nan' in 'field list' at index 2
# Error: Unknown column 'nan' in 'field list' at index 3
# Error: Unknown column 'nan' in 'field list' at index 4
# Error: Unknown column 'nan' in 'field list' at index 5
# Error: Unknown column 'nan' in 'field list' at index 6
# Error: Unknown column 'nan' in 'field list' at index 7
# Error: Unknown column 'nan' in 'field list' at index 8
# Error: Unknown column 'nan' in 'field list' at index 9
# Error: Unknown column 'nan' in 'field list' at index 10
# Error: Unknown column 'nan' in 'field list' at index 11
# Error: Unknown column 'nan' in 'field list' at index 12
# Error: Unknown column 'nan' in 'field list' at index 14
# Error: Unknown column 'nan' in 'field list' at index 15
# Error: Unknown column 'nan' in 'field list' at index 16
# Error: Unknown column 'nan' in 'field list' at index 17
# Error: Unknown column 'nan' in 'field list' at index 18
# Error: Unknown column 'nan' in 'field list' at index 19
# Error: Unknown column 'nan' in 'field list' at index 20
# Error: Unknown column 'nan' in 'field list' at index 21
# Error: Unknown column 'nan' in 'field list' at index 22
# Error: Unknown column 'nan' in 'field list' at index 24
# Error: Unknown column 'nan' in 'field list' at index 25
# Error: Unknown column 'nan' in 'field list' at index 26
# Error: Unknown column 'nan' in 'field list' at index 28
# Error: Unknown column 'nan' in 'field list' at index 29
# Error: Unknown column 'nan' in 'field list' at index 30
# Error: Unknown column 'nan' in 'field list' at index 31
# Error: Unknown column 'nan' in 'field list' at index 32
# Error: Unknown column 'nan' in 'field list' at index 33
# Error: Unknown column 'nan' in 'field list' at index 34
# Error: Unknown column 'nan' in 'field list' at index 35
# Error: Unknown column 'nan' in 'field list' at index 37
# Error: Unknown column 'nan' in 'field list' at index 38
# Error: Unknown column 'nan' in 'field list' at index 39
# Error: Unknown column 'nan' in 'field list' at index 40
# Error: Unknown column 'nan' in 'field list' at index 41
# Error: Unknown column 'nan' in 'field list' at index 42
# Error: Unknown column 'nan' in 'field list' at index 43
# Error: Unknown column 'nan' in 'field list' at index 44
# Error: Unknown column 'nan' in 'field list' at index 45
# Error: Unknown column 'nan' in 'field list' at index 46
# Error: Unknown column 'nan' in 'field list' at index 47
# Error: Unknown column 'nan' in 'field list' at index 48
# Error: Unknown column 'nan' in 'field list' at index 49
# Error: Unknown column 'nan' in 'field list' at index 50
# Error: Unknown column 'nan' in 'field list' at index 51
# Error: Unknown column 'nan' in 'field list' at index 52
# Error: Unknown column 'nan' in 'field list' at index 53
# Error: Unknown column 'nan' in 'field list' at index 54
# Error: Unknown column 'nan' in 'field list' at index 55
# Error: Unknown column 'nan' in 'field list' at index 56
# Error: Unknown column 'nan' in 'field list' at index 57
# Error: Unknown column 'nan' in 'field list' at index 58
# Error: Unknown column 'nan' in 'field list' at index 59
# Error: Unknown column 'nan' in 'field list' at index 60
# Error: Unknown column 'nan' in 'field list' at index 61
# Error: Unknown column 'nan' in 'field list' at index 62
# Error: Unknown column 'nan' in 'field list' at index 63
# Error: Unknown column 'nan' in 'field list' at index 64
# Error: Unknown column 'nan' in 'field list' at index 65
# Error: Unknown column 'nan' in 'field list' at index 66
# Error: Unknown column 'nan' in 'field list' at index 67
# Error: Unknown column 'nan' in 'field list' at index 68
# Error: Unknown column 'nan' in 'field list' at index 69
# Error: Unknown column 'nan' in 'field list' at index 70
# Error: Unknown column 'nan' in 'field list' at index 71
# Error: Unknown column 'nan' in 'field list' at index 72
# Error: Unknown column 'nan' in 'field list' at index 73
# Error: Unknown column 'nan' in 'field list' at index 74
# Error: Unknown column 'nan' in 'field list' at index 75
# Error: Unknown column 'nan' in 'field list' at index 76
# Error: Unknown column 'nan' in 'field list' at index 77
# Error: Unknown column 'nan' in 'field list' at index 78
# Error: Unknown column 'nan' in 'field list' at index 79
# Error: Unknown column 'nan' in 'field list' at index 80
# Error: Unknown column 'nan' in 'field list' at index 81
# Error: Unknown column 'nan' in 'field list' at index 82
# Error: Unknown column 'nan' in 'field list' at index 83
# Error: Unknown column 'nan' in 'field list' at index 84
# Error: Unknown column 'nan' in 'field list' at index 85
# Error: Unknown column 'nan' in 'field list' at index 86
# Error: Unknown column 'nan' in 'field list' at index 87
# Error: Unknown column 'nan' in 'field list' at index 88
# Error: Unknown column 'nan' in 'field list' at index 89
# Error: Unknown column 'nan' in 'field list' at index 90
# Error: Unknown column 'nan' in 'field list' at index 91
# Error: Unknown column 'nan' in 'field list' at index 92
# Error: Unknown column 'nan' in 'field list' at index 93
# Error: Unknown column 'nan' in 'field list' at index 94
# Error: Unknown column 'nan' in 'field list' at index 95
# Error: Unknown column 'nan' in 'field list' at index 96
# Error: Unknown column 'nan' in 'field list' at index 97
# Error: Unknown column 'nan' in 'field list' at index 98
# Error: Unknown column 'nan' in 'field list' at index 99
# Error: Unknown column 'nan' in 'field list' at index 100
# Error: Unknown column 'nan' in 'field list' at index 101
# Error: Unknown column 'nan' in 'field list' at index 102
# Error: Unknown column 'nan' in 'field list' at index 103
# Error: Unknown column 'nan' in 'field list' at index 104
# Error: Unknown column 'nan' in 'field list' at index 105
# Error: Unknown column 'nan' in 'field list' at index 106
# Error: Unknown column 'nan' in 'field list' at index 107
# Error: Unknown column 'nan' in 'field list' at index 108
# Error: Unknown column 'nan' in 'field list' at index 109
# Error: Unknown column 'nan' in 'field list' at index 110
# Error: Unknown column 'nan' in 'field list' at index 111
# Error: Unknown column 'nan' in 'field list' at index 112
# Error: Unknown column 'nan' in 'field list' at index 113
# Error: Unknown column 'nan' in 'field list' at index 114
# Error: Unknown column 'nan' in 'field list' at index 115
# Error: Unknown column 'nan' in 'field list' at index 116
# Error: Unknown column 'nan' in 'field list' at index 117
# Error: Unknown column 'nan' in 'field list' at index 118
# Error: Unknown column 'nan' in 'field list' at index 119
# Error: Unknown column 'nan' in 'field list' at index 120
# Error: Unknown column 'nan' in 'field list' at index 121
# Error: Unknown column 'nan' in 'field list' at index 122
# Error: Unknown column 'nan' in 'field list' at index 123
# Error: Unknown column 'nan' in 'field list' at index 124
# Error: Unknown column 'nan' in 'field list' at index 125
# Error: Unknown column 'nan' in 'field list' at index 126
# Error: Unknown column 'nan' in 'field list' at index 127
# Error: Unknown column 'nan' in 'field list' at index 128
# Error: Unknown column 'nan' in 'field list' at index 129
# Error: Unknown column 'nan' in 'field list' at index 130
# Error: Unknown column 'nan' in 'field list' at index 131
# Error: Unknown column 'nan' in 'field list' at index 132
# Error: Unknown column 'nan' in 'field list' at index 133
# Error: Unknown column 'nan' in 'field list' at index 134
# Error: Unknown column 'nan' in 'field list' at index 135
# Error: Unknown column 'nan' in 'field list' at index 136
# Error: Unknown column 'nan' in 'field list' at index 137
# Error: Unknown column 'nan' in 'field list' at index 138
# Error: Unknown column 'nan' in 'field list' at index 139
# Error: Unknown column 'nan' in 'field list' at index 140
# Error: Unknown column 'nan' in 'field list' at index 141
# Error: Unknown column 'nan' in 'field list' at index 142
# Error: Unknown column 'nan' in 'field list' at index 143
# Error: Unknown column 'nan' in 'field list' at index 144
# Error: Unknown column 'nan' in 'field list' at index 145
# Error: Unknown column 'nan' in 'field list' at index 146
# Error: Unknown column 'nan' in 'field list' at index 147
# Error: Unknown column 'nan' in 'field list' at index 148
# Error: Unknown column 'nan' in 'field list' at index 149
# Error: Unknown column 'nan' in 'field list' at index 150
# Error: Unknown column 'nan' in 'field list' at index 151
# Error: Unknown column 'nan' in 'field list' at index 152
# Error: Unknown column 'nan' in 'field list' at index 153
# Error: Unknown column 'nan' in 'field list' at index 154
# Error: Unknown column 'nan' in 'field list' at index 155
# Error: Unknown column 'nan' in 'field list' at index 156
# Error: Unknown column 'nan' in 'field list' at index 157
# Error: Unknown column 'nan' in 'field list' at index 158
# Error: Unknown column 'nan' in 'field list' at index 159
# Error: Unknown column 'nan' in 'field list' at index 161
# Error: Unknown column 'nan' in 'field list' at index 162
# Error: Unknown column 'nan' in 'field list' at index 163
# Error: Unknown column 'nan' in 'field list' at index 164
# Error: Unknown column 'nan' in 'field list' at index 165
# Error: Unknown column 'nan' in 'field list' at index 167
# Error: Unknown column 'nan' in 'field list' at index 168
# Error: Unknown column 'nan' in 'field list' at index 169
# Error: Unknown column 'nan' in 'field list' at index 170
# Error: Unknown column 'nan' in 'field list' at index 171
# Error: Unknown column 'nan' in 'field list' at index 172
# Error: Unknown column 'nan' in 'field list' at index 174
# Error: Unknown column 'nan' in 'field list' at index 176
# Error: Unknown column 'nan' in 'field list' at index 177
# Error: Unknown column 'nan' in 'field list' at index 178
# Error: Unknown column 'nan' in 'field list' at index 179
# Error: Unknown column 'nan' in 'field list' at index 181
# Error: Unknown column 'nan' in 'field list' at index 182
# Error: Unknown column 'nan' in 'field list' at index 184
# Error: Unknown column 'nan' in 'field list' at index 185
# Error: Unknown column 'nan' in 'field list' at index 186
# Error: Unknown column 'nan' in 'field list' at index 187
# Error: Unknown column 'nan' in 'field list' at index 189
# Error: Unknown column 'nan' in 'field list' at index 191
# Data insertion complete.

# %%
data
# Out:
#                    Name Currency   Type         Sub type              Market  \
# 0                 ACCOR      EUR  Stock  Ordinary Shares      Euronext Paris
# 1           AIR LIQUIDE      EUR  Stock  Ordinary Shares      Euronext Paris
# 2             AIRBUS SE      EUR  Stock  Ordinary Shares      Euronext Paris
# 3      ARCELORMITTAL SA      EUR  Stock  Ordinary Shares  Euronext Amsterdam
# 4                   AXA      EUR  Stock  Ordinary Shares      Euronext Paris
# ..                  ...      ...    ...              ...                 ...
# 185          STELLANTIS      EUR  Stock  Ordinary Shares      Euronext Milan
# 186  STMICROELECTRONICS      EUR  Stock  Ordinary Shares      Euronext Milan
# 187      TELECOM ITALIA      EUR  Stock  Ordinary Shares      Euronext Milan
# 189               TERNA      EUR  Stock  Ordinary Shares      Euronext Milan
# 191              UNIPOL      EUR  Stock  Ordinary Shares      Euronext Milan
#
#         ISIN Code                    Industry  \
# 0    FR0000120404  40, Consumer Discretionary
# 1    FR0000120073         55, Basic Materials
# 2    NL0000235190             50, Industrials
# 3    LU1598757687         55, Basic Materials
# 4    FR0000120628              30, Financials
# ..            ...                         ...
# 185  NL00150001Q9  40, Consumer Discretionary
# 186  NL0000226223              10, Technology
# 187  IT0003497168      15, Telecommunications
# 189  IT0003242622               65, Utilities
# 191  IT0004810054              30, Financials
#
#                              SuperSector  \
# 0               4050, Travel and Leisure
# 1                        5520, Chemicals
# 2    5020, Industrial Goods and Services
# 3                  5510, Basic Resources
# 4                        3030, Insurance
# ..                                   ...
# 185          4010, Automobiles and Parts
# 186                     1010, Technology
# 187             1510, Telecommunications
# 189                      6510, Utilities
# 191                      3030, Insurance
#
#                                            Sector  \
# 0                      405010, Travel and Leisure
# 1                               552010, Chemicals
# 2                   502010, Aerospace and Defense
# 3            551020, Industrial Metals and Mining
# 4                      303020, Non-life Insurance
# ..                                            ...
# 185                 401010, Automobiles and Parts
# 186     101020, Technology Hardware and Equipment
# 187  151020, Telecommunications Service Providers
# 189                           651010, Electricity
# 191                    303020, Non-life Insurance
#
#                                  Subsector  ...  Number of board members  \
# 0              40501025, Hotels and Motels  ...                     13.0
# 1            55201020, Specialty Chemicals  ...                     14.0
# 2                      50201010, Aerospace  ...                     12.0
# 3                 55102010, Iron and Steel  ...                     10.0
# 4            30302010, Full Line Insurance  ...                     16.0
# ..                                     ...  ...                      ...
# 185                  40101020, Automobiles  ...                     11.0
# 186               10102010, Semiconductors  ...                      9.0
# 187  15102015, Telecommunications Services  ...                     15.0
# 189     65101015, Conventional Electricity  ...                     13.0
# 191          30302010, Full Line Insurance  ...                     15.0
#
#      Market Cap in USD  \
# 0         1.033192e+10
# 1         1.051361e+11
# 2         1.361650e+11
# 3         2.175417e+10
# 4         8.254087e+10
# ..                 ...
# 185       8.246704e+10
# 186       3.663359e+10
# 187       3.591990e+09
# 189       1.562735e+10
# 191       6.241310e+09
#
#      Carbon footprint (total GHG emissions / enterprise value)_in_USD  \
# 0                                           572.631900
# 1                                                  NaN
# 2                                                  NaN
# 3                                          3373.201000
# 4                                             2.717800
# ..                                                 ...
# 185                                        6858.244394
# 186                                          27.984900
# 187                                         133.632300
# 189                                         141.369684
# 191                                         509.708945
#
#      Share of women in total workforce in %  \
# 0                                       NaN
# 1                                     0.280
# 2                                     0.200
# 3                                       NaN
# 4                                       NaN
# ..                                      ...
# 185                                     NaN
# 186                                     NaN
# 187                                   0.380
# 189                                   0.161
# 191                                   0.543
#
#      Share of women in management bodies in %  Gender pay gap in %  \
# 0                                         NaN                  NaN
# 1                                       0.300                  NaN
# 2                                         NaN                  NaN
# 3                                       0.157                  NaN
# 4                                       0.353                  NaN
# ..                                        ...                  ...
# 185                                       NaN                  NaN
# 186                                       NaN                  NaN
# 187                                     0.280                  NaN
# 189                                     0.237                 0.19
# 191                                     0.162                 0.09
#
#      Rate of employees with disabilities in %  \
# 0                                         NaN
# 1                                       0.045
# 2                                         NaN
# 3                                         NaN
# 4                                       0.007
# ..                                        ...
# 185                                       NaN
# 186                                       NaN
# 187                                     0.030
# 189                                       NaN
# 191                                       NaN
#
#      Board gender diversity (female board members / total board members) in %  \
# 0                                                0.615
# 1                                                0.357
# 2                                                0.333
# 3                                                0.300
# 4                                                0.563
# ..                                                 ...
# 185                                              0.273
# 186                                              0.444
# 187                                              0.400
# 189                                              0.461
# 191                                              0.400
#
#      Total energy consumption in mwh  Rate of resignation in %
# 0                       1.371200e+07                       NaN
# 1                                NaN                     0.086
# 2                       3.717000e+06                       NaN
# 3                       3.866670e+08                       NaN
# 4                       2.236380e+05                     0.100
# ..                               ...                       ...
# 185                     1.549489e+07                       NaN
# 186                     2.878880e+06                       NaN
# 187                     2.671000e+06                       NaN
# 189                     2.578550e+05                     0.018
# 191                     1.474418e+05                     0.027
#
# [187 rows x 22 columns]

# %%
# Überprüfung und Ausgabe der Daten, um sicherzustellen, dass keine 'nan' Werte vorhanden sind
data = data.applymap(lambda x: None if pd.isna(x) or x == 'nan' else x)
for index, row in data.iterrows():
    if any(pd.isna(x) for x in row):
        print(f"NaN still in row {index}: {row}")
    elif any(x == 'nan' for x in row):
        print(f"'nan' string in row {index}: {row}")
# Out:
# NaN still in row 0: Name                                                                                              ACCOR
# Currency                                                                                            EUR
# Type                                                                                              Stock
# Sub type                                                                                Ordinary Shares
# Market                                                                                   Euronext Paris
# ISIN Code                                                                                  FR0000120404
# Industry                                                                     40, Consumer Discretionary
# SuperSector                                                                    4050, Travel and Leisure
# Sector                                                                       405010, Travel and Leisure
# Subsector                                                                   40501025, Hotels and Motels
# Average training hours per employee                                                                 NaN
# Number of female board members                                                                      8.0
# Number of board members                                                                            13.0
# Market Cap in USD                                                                         10331920000.0
# Carbon footprint (total GHG emissions / enterprise value)_in_USD                               572.6319
# Share of women in total workforce in %                                                              NaN
# Share of women in management bodies in %                                                            NaN
# Gender pay gap in %                                                                                 NaN
# Rate of employees with disabilities in %                                                            NaN
# Board gender diversity (female board members / total board members) in %                          0.615
# Total energy consumption in mwh                                                              13712000.0
# Rate of resignation in %                                                                            NaN
# Name: 0, dtype: object
# NaN still in row 1: Name                                                                                          AIR LIQUIDE
# Currency                                                                                              EUR
# Type                                                                                                Stock
# Sub type                                                                                  Ordinary Shares
# Market                                                                                     Euronext Paris
# ISIN Code                                                                                    FR0000120073
# Industry                                                                              55, Basic Materials
# SuperSector                                                                               5520, Chemicals
# Sector                                                                                  552010, Chemicals
# Subsector                                                                   55201020, Specialty Chemicals
# Average training hours per employee                                                                  20.0
# Number of female board members                                                                        5.0
# Number of board members                                                                              14.0
# Market Cap in USD                                                                          105136060000.0
# Carbon footprint (total GHG emissions / enterprise value)_in_USD                                      NaN
# Share of women in total workforce in %                                                               0.28
# Share of women in management bodies in %                                                              0.3
# Gender pay gap in %                                                                                   NaN
# Rate of employees with disabilities in %                                                            0.045
# Board gender diversity (female board members / total board members) in %                            0.357
# Total energy consumption in mwh                                                                       NaN
# Rate of resignation in %                                                                            0.086
# Name: 1, dtype: object
# NaN still in row 2: Name                                                                                                  AIRBUS SE
# Currency                                                                                                    EUR
# Type                                                                                                      Stock
# Sub type                                                                                        Ordinary Shares
# Market                                                                                           Euronext Paris
# ISIN Code                                                                                          NL0000235190
# Industry                                                                                        50, Industrials
# SuperSector                                                                 5020, Industrial Goods and Services
# Sector                                                                            502010, Aerospace and Defense
# Subsector                                                                                   50201010, Aerospace
# Average training hours per employee                                                                        15.0
# Number of female board members                                                                              4.0
# Number of board members                                                                                    12.0
# Market Cap in USD                                                                           136164990000.000015
# Carbon footprint (total GHG emissions / enterprise value)_in_USD                                            NaN
# Share of women in total workforce in %                                                                      0.2
# Share of women in management bodies in %                                                                    NaN
# Gender pay gap in %                                                                                         NaN
# Rate of employees with disabilities in %                                                                    NaN
# Board gender diversity (female board members / total board members) in %                                  0.333
# Total energy consumption in mwh                                                                       3717000.0
# Rate of resignation in %                                                                                    NaN
# Name: 2, dtype: object
# NaN still in row 3: Name                                                                                            ARCELORMITTAL SA
# Currency                                                                                                     EUR
# Type                                                                                                       Stock
# Sub type                                                                                         Ordinary Shares
# Market                                                                                        Euronext Amsterdam
# ISIN Code                                                                                           LU1598757687
# Industry                                                                                     55, Basic Materials
# SuperSector                                                                                5510, Basic Resources
# Sector                                                                      551020, Industrial Metals and Mining
# Subsector                                                                               55102010, Iron and Steel
# Average training hours per employee                                                                          NaN
# Number of female board members                                                                               3.0
# Number of board members                                                                                     10.0
# Market Cap in USD                                                                                  21754170000.0
# Carbon footprint (total GHG emissions / enterprise value)_in_USD                                        3373.201
# Share of women in total workforce in %                                                                       NaN
# Share of women in management bodies in %                                                                   0.157
# Gender pay gap in %                                                                                          NaN
# Rate of employees with disabilities in %                                                                     NaN
# Board gender diversity (female board members / total board members) in %                                     0.3
# Total energy consumption in mwh                                                                      386666976.0
# Rate of resignation in %                                                                                     NaN
# Name: 3, dtype: object
# NaN still in row 4: Name                                                                                                  AXA
# Currency                                                                                              EUR
# Type                                                                                                Stock
# Sub type                                                                                  Ordinary Shares
# Market                                                                                     Euronext Paris
# ISIN Code                                                                                    FR0000120628
# Industry                                                                                   30, Financials
# SuperSector                                                                               3030, Insurance
# Sector                                                                         303020, Non-life Insurance
# Subsector                                                                   30302010, Full Line Insurance
# Average training hours per employee                                                                   NaN
# Number of female board members                                                                        9.0
# Number of board members                                                                              16.0
# Market Cap in USD                                                                           82540870000.0
# Carbon footprint (total GHG emissions / enterprise value)_in_USD                                   2.7178
# Share of women in total workforce in %                                                                NaN
# Share of women in management bodies in %                                                            0.353
# Gender pay gap in %                                                                                   NaN
# Rate of employees with disabilities in %                                                            0.007
# Board gender diversity (female board members / total board members) in %                            0.563
# Total energy consumption in mwh                                                                  223638.0
# Rate of resignation in %                                                                              0.1
# Name: 4, dtype: object
# NaN still in row 5: Name                                                                        BNP PARIBAS ACT.A
# Currency                                                                                  EUR
# Type                                                                                    Stock
# Sub type                                                                      Ordinary Shares
# Market                                                                         Euronext Paris
# ISIN Code                                                                        FR0000131104
# Industry                                                                       30, Financials
# SuperSector                                                                       3010, Banks
# Sector                                                                          301010, Banks
# Subsector                                                                     30101010, Banks
# Average training hours per employee                                                      24.2
# Number of female board members                                                            7.0
# Number of board members                                                                  13.0
# Market Cap in USD                                                               80076660000.0
# Carbon footprint (total GHG emissions / enterprise value)_in_USD                          NaN
# Share of women in total workforce in %                                                   0.51
# Share of women in management bodies in %                                                  NaN
# Gender pay gap in %                                                                       NaN
# Rate of employees with disabilities in %                                                0.027
# Board gender diversity (female board members / total board members) in %                0.538
# Total energy consumption in mwh                                                      830000.0
# Rate of resignation in %                                                                  NaN
# Name: 5, dtype: object
# NaN still in row 6: Name                                                                                                  BOUYGUES
# Currency                                                                                                   EUR
# Type                                                                                                     Stock
# Sub type                                                                                       Ordinary Shares
# Market                                                                                          Euronext Paris
# ISIN Code                                                                                         FR0000120503
# Industry                                                                                       50, Industrials
# SuperSector                                                                   5010, Construction and Materials
# Sector                                                                      501010, Construction and Materials
# Subsector                                                                               50101010, Construction
# Average training hours per employee                                                                        NaN
# Number of female board members                                                                             8.0
# Number of board members                                                                                   14.0
# Market Cap in USD                                                                                14690030000.0
# Carbon footprint (total GHG emissions / enterprise value)_in_USD                                      767.1686
# Share of women in total workforce in %                                                                     NaN
# Share of women in management bodies in %                                                                   NaN
# Gender pay gap in %                                                                                        NaN
# Rate of employees with disabilities in %                                                                   NaN
# Board gender diversity (female board members / total board members) in %                                 0.571
# Total energy consumption in mwh                                                                            NaN
# Rate of resignation in %                                                                                   NaN
# Name: 6, dtype: object
# NaN still in row 7: Name                                                                                                     CAPGEMINI
# Currency                                                                                                       EUR
# Type                                                                                                         Stock
# Sub type                                                                                           Ordinary Shares
# Market                                                                                              Euronext Paris
# ISIN Code                                                                                             FR0000125338
# Industry                                                                                            10, Technology
# SuperSector                                                                                       1010, Technology
# Sector                                                                      101010, Software and Computer Services
# Subsector                                                                              10101010, Computer Services
# Average training hours per employee                                                                           52.4
# Number of female board members                                                                                 6.0
# Number of board members                                                                                       15.0
# Market Cap in USD                                                                                    37140770000.0
# Carbon footprint (total GHG emissions / enterprise value)_in_USD                                           23.6684
# Share of women in total workforce in %                                                                       0.388
# Share of women in management bodies in %                                                                     0.273
# Gender pay gap in %                                                                                            NaN
# Rate of employees with disabilities in %                                                                     0.012
# Board gender diversity (female board members / total board members) in %                                       0.4
# Total energy consumption in mwh                                                                           201053.0
# Rate of resignation in %                                                                                       NaN
# Name: 7, dtype: object
# NaN still in row 8: Name                                                                                                             CARREFOUR
# Currency                                                                                                               EUR
# Type                                                                                                                 Stock
# Sub type                                                                                                   Ordinary Shares
# Market                                                                                                      Euronext Paris
# ISIN Code                                                                                                     FR0000120172
# Industry                                                                                              45, Consumer Staples
# SuperSector                                                                   4520, Personal Care, Drug and Grocery Stores
# Sector                                                                      452010, Personal Care, Drug and Grocery Stores
# Subsector                                                                         45201010, Food Retailers and Wholesalers
# Average training hours per employee                                                                                    9.2
# Number of female board members                                                                                         7.0
# Number of board members                                                                                               15.0
# Market Cap in USD                                                                                            11936920000.0
# Carbon footprint (total GHG emissions / enterprise value)_in_USD                                                       NaN
# Share of women in total workforce in %                                                                                0.55
# Share of women in management bodies in %                                                                             0.308
# Gender pay gap in %                                                                                                    NaN
# Rate of employees with disabilities in %                                                                             0.043
# Board gender diversity (female board members / total board members) in %                                             0.467
# Total energy consumption in mwh                                                                                  4556990.0
# Rate of resignation in %                                                                                             0.158
# Name: 8, dtype: object
# NaN still in row 9: Name                                                                        CREDIT AGRICOLE
# Currency                                                                                EUR
# Type                                                                                  Stock
# Sub type                                                                    Ordinary Shares
# Market                                                                       Euronext Paris
# ISIN Code                                                                      FR0000045072
# Industry                                                                     30, Financials
# SuperSector                                                                     3010, Banks
# Sector                                                                        301010, Banks
# Subsector                                                                   30101010, Banks
# Average training hours per employee                                                    33.5
# Number of female board members                                                         10.0
# Number of board members                                                                21.0
# Market Cap in USD                                                             44858680000.0
# Carbon footprint (total GHG emissions / enterprise value)_in_USD                        NaN
# Share of women in total workforce in %                                                0.522
# Share of women in management bodies in %                                              0.353
# Gender pay gap in %                                                                     NaN
# Rate of employees with disabilities in %                                              0.054
# Board gender diversity (female board members / total board members) in %              0.476
# Total energy consumption in mwh                                                    398861.0
# Rate of resignation in %                                                               0.04
# Name: 9, dtype: object
# NaN still in row 10: Name                                                                                                  DANONE
# Currency                                                                                                 EUR
# Type                                                                                                   Stock
# Sub type                                                                                     Ordinary Shares
# Market                                                                                        Euronext Paris
# ISIN Code                                                                                       FR0000120644
# Industry                                                                                45, Consumer Staples
# SuperSector                                                                 4510, Food, Beverage and Tobacco
# Sector                                                                                451020, Food Producers
# Subsector                                                                            45102020, Food Products
# Average training hours per employee                                                                      NaN
# Number of female board members                                                                           NaN
# Number of board members                                                                                  NaN
# Market Cap in USD                                                                              42715470000.0
# Carbon footprint (total GHG emissions / enterprise value)_in_USD                                         NaN
# Share of women in total workforce in %                                                                   NaN
# Share of women in management bodies in %                                                                 NaN
# Gender pay gap in %                                                                                      NaN
# Rate of employees with disabilities in %                                                                 NaN
# Board gender diversity (female board members / total board members) in %                                 NaN
# Total energy consumption in mwh                                                                          NaN
# Rate of resignation in %                                                                                 NaN
# Name: 10, dtype: object
# NaN still in row 11: Name                                                                                             DASSAULT SYSTEMES
# Currency                                                                                                       EUR
# Type                                                                                                         Stock
# Sub type                                                                                           Ordinary Shares
# Market                                                                                              Euronext Paris
# ISIN Code                                                                                             FR0014003TT8
# Industry                                                                                            10, Technology
# SuperSector                                                                                       1010, Technology
# Sector                                                                      101010, Software and Computer Services
# Subsector                                                                                       10101015, Software
# Average training hours per employee                                                                           27.9
# Number of female board members                                                                                 6.0
# Number of board members                                                                                       12.0
# Market Cap in USD                                                                                    54964830000.0
# Carbon footprint (total GHG emissions / enterprise value)_in_USD                                          3.915023
# Share of women in total workforce in %                                                                       0.281
# Share of women in management bodies in %                                                                     0.385
# Gender pay gap in %                                                                                            NaN
# Rate of employees with disabilities in %                                                                     0.027
# Board gender diversity (female board members / total board members) in %                                       0.5
# Total energy consumption in mwh                                                                            82766.0
# Rate of resignation in %                                                                                       NaN
# Name: 11, dtype: object
# NaN still in row 12: Name                                                                                                          EDENRED
# Currency                                                                                                          EUR
# Type                                                                                                            Stock
# Sub type                                                                                              Ordinary Shares
# Market                                                                                                 Euronext Paris
# ISIN Code                                                                                                FR0010908533
# Industry                                                                                              50, Industrials
# SuperSector                                                                       5020, Industrial Goods and Services
# Sector                                                                            502050, Industrial Support Services
# Subsector                                                                   50205015, Transaction Processing Services
# Average training hours per employee                                                                              22.1
# Number of female board members                                                                                    6.0
# Number of board members                                                                                          12.0
# Market Cap in USD                                                                                       12471920000.0
# Carbon footprint (total GHG emissions / enterprise value)_in_USD                                               6.5912
# Share of women in total workforce in %                                                                           0.52
# Share of women in management bodies in %                                                                         0.37
# Gender pay gap in %                                                                                               NaN
# Rate of employees with disabilities in %                                                                        0.055
# Board gender diversity (female board members / total board members) in %                                          0.5
# Total energy consumption in mwh                                                                            11713829.0
# Rate of resignation in %                                                                                          NaN
# Name: 12, dtype: object
# NaN still in row 14: Name                                                                                              ESSILORLUXOTTICA
# Currency                                                                                                       EUR
# Type                                                                                                         Stock
# Sub type                                                                                           Ordinary Shares
# Market                                                                                              Euronext Paris
# ISIN Code                                                                                             FR0000121667
# Industry                                                                                           20, Health Care
# SuperSector                                                                                      2010, Health Care
# Sector                                                                      201020, Medical Equipment and Services
# Subsector                                                                               20102015, Medical Supplies
# Average training hours per employee                                                                           19.2
# Number of female board members                                                                                 6.0
# Number of board members                                                                                       14.0
# Market Cap in USD                                                                                    99406210000.0
# Carbon footprint (total GHG emissions / enterprise value)_in_USD                                           14.0384
# Share of women in total workforce in %                                                                         0.6
# Share of women in management bodies in %                                                                      0.39
# Gender pay gap in %                                                                                            NaN
# Rate of employees with disabilities in %                                                                       NaN
# Board gender diversity (female board members / total board members) in %                                     0.429
# Total energy consumption in mwh                                                                          2149000.0
# Rate of resignation in %                                                                                       NaN
# Name: 14, dtype: object
# NaN still in row 15: Name                                                                                              EUROFINS SCIENT.
# Currency                                                                                                       EUR
# Type                                                                                                         Stock
# Sub type                                                                                           Ordinary Shares
# Market                                                                                              Euronext Paris
# ISIN Code                                                                                             FR0014000MR3
# Industry                                                                                           20, Health Care
# SuperSector                                                                                      2010, Health Care
# Sector                                                                      201020, Medical Equipment and Services
# Subsector                                                                               20102020, Medical Services
# Average training hours per employee                                                                            NaN
# Number of female board members                                                                                 4.0
# Number of board members                                                                                        8.0
# Market Cap in USD                                                                                    12331750000.0
# Carbon footprint (total GHG emissions / enterprise value)_in_USD                                         34.143914
# Share of women in total workforce in %                                                                        0.57
# Share of women in management bodies in %                                                                      0.21
# Gender pay gap in %                                                                                            NaN
# Rate of employees with disabilities in %                                                                       NaN
# Board gender diversity (female board members / total board members) in %                                       0.5
# Total energy consumption in mwh                                                                           742007.0
# Rate of resignation in %                                                                                       NaN
# Name: 15, dtype: object
# NaN still in row 16: Name                                                                                                 HERMES INTL
# Currency                                                                                                     EUR
# Type                                                                                                       Stock
# Sub type                                                                                         Ordinary Shares
# Market                                                                                            Euronext Paris
# ISIN Code                                                                                           FR0000052292
# Industry                                                                              40, Consumer Discretionary
# SuperSector                                                                 4020, Consumer Products and Services
# Sector                                                                                    402040, Personal Goods
# Subsector                                                                     40204020, Clothing and Accessories
# Average training hours per employee                                                                         21.0
# Number of female board members                                                                               7.0
# Number of board members                                                                                     14.0
# Market Cap in USD                                                                            263646930000.000031
# Carbon footprint (total GHG emissions / enterprise value)_in_USD                                             NaN
# Share of women in total workforce in %                                                                      0.67
# Share of women in management bodies in %                                                                     0.4
# Gender pay gap in %                                                                                          NaN
# Rate of employees with disabilities in %                                                                   0.069
# Board gender diversity (female board members / total board members) in %                                     0.5
# Total energy consumption in mwh                                                                         209100.0
# Rate of resignation in %                                                                                     NaN
# Name: 16, dtype: object
# NaN still in row 17: Name                                                                                                      KERING
# Currency                                                                                                     EUR
# Type                                                                                                       Stock
# Sub type                                                                                         Ordinary Shares
# Market                                                                                            Euronext Paris
# ISIN Code                                                                                           FR0000121485
# Industry                                                                              40, Consumer Discretionary
# SuperSector                                                                 4020, Consumer Products and Services
# Sector                                                                                    402040, Personal Goods
# Subsector                                                                     40204020, Clothing and Accessories
# Average training hours per employee                                                                         13.1
# Number of female board members                                                                               7.0
# Number of board members                                                                                     11.0
# Market Cap in USD                                                                                  44893990000.0
# Carbon footprint (total GHG emissions / enterprise value)_in_USD                                         42.4362
# Share of women in total workforce in %                                                                      0.63
# Share of women in management bodies in %                                                                    0.42
# Gender pay gap in %                                                                                        0.142
# Rate of employees with disabilities in %                                                                   0.015
# Board gender diversity (female board members / total board members) in %                                   0.636
# Total energy consumption in mwh                                                                         351130.0
# Rate of resignation in %                                                                                     NaN
# Name: 17, dtype: object
# NaN still in row 18: Name                                                                                                     L'OREAL
# Currency                                                                                                     EUR
# Type                                                                                                       Stock
# Sub type                                                                                         Ordinary Shares
# Market                                                                                            Euronext Paris
# ISIN Code                                                                                           FR0000120321
# Industry                                                                              40, Consumer Discretionary
# SuperSector                                                                 4020, Consumer Products and Services
# Sector                                                                                    402040, Personal Goods
# Subsector                                                                                    40204035, Cosmetics
# Average training hours per employee                                                                         36.7
# Number of female board members                                                                               7.0
# Number of board members                                                                                     16.0
# Market Cap in USD                                                                                 242280100000.0
# Carbon footprint (total GHG emissions / enterprise value)_in_USD                                         49.2842
# Share of women in total workforce in %                                                                      0.68
# Share of women in management bodies in %                                                                    0.32
# Gender pay gap in %                                                                                        0.007
# Rate of employees with disabilities in %                                                                   0.019
# Board gender diversity (female board members / total board members) in %                                   0.438
# Total energy consumption in mwh                                                                         935591.0
# Rate of resignation in %                                                                                     NaN
# Name: 18, dtype: object
# NaN still in row 19: Name                                                                                                            LEGRAND
# Currency                                                                                                            EUR
# Type                                                                                                              Stock
# Sub type                                                                                                Ordinary Shares
# Market                                                                                                   Euronext Paris
# ISIN Code                                                                                                  FR0010307819
# Industry                                                                                                50, Industrials
# SuperSector                                                                         5020, Industrial Goods and Services
# Sector                                                                      502020, Electronic and Electrical Equipment
# Subsector                                                                               50202010, Electrical Components
# Average training hours per employee                                                                                22.0
# Number of female board members                                                                                      6.0
# Number of board members                                                                                            14.0
# Market Cap in USD                                                                                         27149110000.0
# Carbon footprint (total GHG emissions / enterprise value)_in_USD                                               468.1464
# Share of women in total workforce in %                                                                              NaN
# Share of women in management bodies in %                                                                           0.25
# Gender pay gap in %                                                                                                 NaN
# Rate of employees with disabilities in %                                                                          0.024
# Board gender diversity (female board members / total board members) in %                                          0.429
# Total energy consumption in mwh                                                                                384000.0
# Rate of resignation in %                                                                                          0.066
# Name: 19, dtype: object
# NaN still in row 20: Name                                                                                                        LVMH
# Currency                                                                                                     EUR
# Type                                                                                                       Stock
# Sub type                                                                                         Ordinary Shares
# Market                                                                                            Euronext Paris
# ISIN Code                                                                                           FR0000121014
# ...
# Share of women in total workforce in %                                                                           0.48
# Share of women in management bodies in %                                                                          NaN
# Gender pay gap in %                                                                                               0.1
# Rate of employees with disabilities in %                                                                          NaN
# Board gender diversity (female board members / total board members) in %                                        0.417
# Total energy consumption in mwh                                                                            172500.138
# Rate of resignation in %                                                                                          NaN
# Name: 182, dtype: object
# NaN still in row 184: Name                                                                                             SNAM
# Currency                                                                                          EUR
# Type                                                                                            Stock
# Sub type                                                                              Ordinary Shares
# Market                                                                                 Euronext Milan
# ISIN Code                                                                                IT0003153415
# Industry                                                                                   60, Energy
# SuperSector                                                                              6010, Energy
# Sector                                                                      601010, Oil, Gas and Coal
# Subsector                                                                         60101035, Pipelines
# Average training hours per employee                                                              33.7
# Number of female board members                                                                    4.0
# Number of board members                                                                           9.0
# Market Cap in USD                                                                       15283880000.0
# Carbon footprint (total GHG emissions / enterprise value)_in_USD                           105.518692
# Share of women in total workforce in %                                                          0.165
# Share of women in management bodies in %                                                        0.197
# Gender pay gap in %                                                                              0.08
# Rate of employees with disabilities in %                                                          NaN
# Board gender diversity (female board members / total board members) in %                        0.444
# Total energy consumption in mwh                                                           4900281.698
# Rate of resignation in %                                                                        0.038
# Name: 184, dtype: object
# NaN still in row 185: Name                                                                                           STELLANTIS
# Currency                                                                                              EUR
# Type                                                                                                Stock
# Sub type                                                                                  Ordinary Shares
# Market                                                                                     Euronext Milan
# ISIN Code                                                                                    NL00150001Q9
# Industry                                                                       40, Consumer Discretionary
# SuperSector                                                                   4010, Automobiles and Parts
# Sector                                                                      401010, Automobiles and Parts
# Subsector                                                                           40101020, Automobiles
# Average training hours per employee                                                                   NaN
# Number of female board members                                                                        3.0
# Number of board members                                                                              11.0
# Market Cap in USD                                                                           82467040000.0
# Carbon footprint (total GHG emissions / enterprise value)_in_USD                              6858.244394
# Share of women in total workforce in %                                                                NaN
# Share of women in management bodies in %                                                              NaN
# Gender pay gap in %                                                                                   NaN
# Rate of employees with disabilities in %                                                              NaN
# Board gender diversity (female board members / total board members) in %                            0.273
# Total energy consumption in mwh                                                                15494891.0
# Rate of resignation in %                                                                              NaN
# Name: 185, dtype: object
# NaN still in row 186: Name                                                                                               STMICROELECTRONICS
# Currency                                                                                                          EUR
# Type                                                                                                            Stock
# Sub type                                                                                              Ordinary Shares
# Market                                                                                                 Euronext Milan
# ISIN Code                                                                                                NL0000226223
# Industry                                                                                               10, Technology
# SuperSector                                                                                          1010, Technology
# Sector                                                                      101020, Technology Hardware and Equipment
# Subsector                                                                                    10102010, Semiconductors
# Average training hours per employee                                                                               NaN
# Number of female board members                                                                                    4.0
# Number of board members                                                                                           9.0
# Market Cap in USD                                                                                       36633590000.0
# Carbon footprint (total GHG emissions / enterprise value)_in_USD                                              27.9849
# Share of women in total workforce in %                                                                            NaN
# Share of women in management bodies in %                                                                          NaN
# Gender pay gap in %                                                                                               NaN
# Rate of employees with disabilities in %                                                                          NaN
# Board gender diversity (female board members / total board members) in %                                        0.444
# Total energy consumption in mwh                                                                           2878880.081
# Rate of resignation in %                                                                                          NaN
# Name: 186, dtype: object
# NaN still in row 187: Name                                                                                                      TELECOM ITALIA
# Currency                                                                                                             EUR
# Type                                                                                                               Stock
# Sub type                                                                                                 Ordinary Shares
# Market                                                                                                    Euronext Milan
# ISIN Code                                                                                                   IT0003497168
# Industry                                                                                          15, Telecommunications
# SuperSector                                                                                     1510, Telecommunications
# Sector                                                                      151020, Telecommunications Service Providers
# Subsector                                                                          15102015, Telecommunications Services
# Average training hours per employee                                                                                53.75
# Number of female board members                                                                                       6.0
# Number of board members                                                                                             15.0
# Market Cap in USD                                                                                           3591990000.0
# Carbon footprint (total GHG emissions / enterprise value)_in_USD                                                133.6323
# Share of women in total workforce in %                                                                              0.38
# Share of women in management bodies in %                                                                            0.28
# Gender pay gap in %                                                                                                  NaN
# Rate of employees with disabilities in %                                                                            0.03
# Board gender diversity (female board members / total board members) in %                                             0.4
# Total energy consumption in mwh                                                                                2671000.0
# Rate of resignation in %                                                                                             NaN
# Name: 187, dtype: object
# NaN still in row 189: Name                                                                                                     TERNA
# Currency                                                                                                   EUR
# Type                                                                                                     Stock
# Sub type                                                                                       Ordinary Shares
# Market                                                                                          Euronext Milan
# ISIN Code                                                                                         IT0003242622
# Industry                                                                                         65, Utilities
# SuperSector                                                                                    6510, Utilities
# Sector                                                                                     651010, Electricity
# Subsector                                                                   65101015, Conventional Electricity
# Average training hours per employee                                                                       36.0
# Number of female board members                                                                             6.0
# Number of board members                                                                                   13.0
# Market Cap in USD                                                                                15627350000.0
# Carbon footprint (total GHG emissions / enterprise value)_in_USD                                    141.369684
# Share of women in total workforce in %                                                                   0.161
# Share of women in management bodies in %                                                                 0.237
# Gender pay gap in %                                                                                       0.19
# Rate of employees with disabilities in %                                                                   NaN
# Board gender diversity (female board members / total board members) in %                                 0.461
# Total energy consumption in mwh                                                                      257855.04
# Rate of resignation in %                                                                                 0.018
# Name: 189, dtype: object
# NaN still in row 191: Name                                                                                               UNIPOL
# Currency                                                                                              EUR
# Type                                                                                                Stock
# Sub type                                                                                  Ordinary Shares
# Market                                                                                     Euronext Milan
# ISIN Code                                                                                    IT0004810054
# Industry                                                                                   30, Financials
# SuperSector                                                                               3030, Insurance
# Sector                                                                         303020, Non-life Insurance
# Subsector                                                                   30302010, Full Line Insurance
# Average training hours per employee                                                                 15.72
# Number of female board members                                                                        6.0
# Number of board members                                                                              15.0
# Market Cap in USD                                                                            6241310000.0
# Carbon footprint (total GHG emissions / enterprise value)_in_USD                               509.708945
# Share of women in total workforce in %                                                              0.543
# Share of women in management bodies in %                                                            0.162
# Gender pay gap in %                                                                                  0.09
# Rate of employees with disabilities in %                                                              NaN
# Board gender diversity (female board members / total board members) in %                              0.4
# Total energy consumption in mwh                                                                147441.785
# Rate of resignation in %                                                                            0.027
# Name: 191, dtype: object
# /tmp/ipykernel_2560/271773376.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   data = data.applymap(lambda x: None if pd.isna(x) or x == 'nan' else x)

# %%
data
# Out:
#                    Name Currency   Type         Sub type              Market  \
# 0                 ACCOR      EUR  Stock  Ordinary Shares      Euronext Paris
# 1           AIR LIQUIDE      EUR  Stock  Ordinary Shares      Euronext Paris
# 2             AIRBUS SE      EUR  Stock  Ordinary Shares      Euronext Paris
# 3      ARCELORMITTAL SA      EUR  Stock  Ordinary Shares  Euronext Amsterdam
# 4                   AXA      EUR  Stock  Ordinary Shares      Euronext Paris
# ..                  ...      ...    ...              ...                 ...
# 185          STELLANTIS      EUR  Stock  Ordinary Shares      Euronext Milan
# 186  STMICROELECTRONICS      EUR  Stock  Ordinary Shares      Euronext Milan
# 187      TELECOM ITALIA      EUR  Stock  Ordinary Shares      Euronext Milan
# 189               TERNA      EUR  Stock  Ordinary Shares      Euronext Milan
# 191              UNIPOL      EUR  Stock  Ordinary Shares      Euronext Milan
#
#         ISIN Code                    Industry  \
# 0    FR0000120404  40, Consumer Discretionary
# 1    FR0000120073         55, Basic Materials
# 2    NL0000235190             50, Industrials
# 3    LU1598757687         55, Basic Materials
# 4    FR0000120628              30, Financials
# ..            ...                         ...
# 185  NL00150001Q9  40, Consumer Discretionary
# 186  NL0000226223              10, Technology
# 187  IT0003497168      15, Telecommunications
# 189  IT0003242622               65, Utilities
# 191  IT0004810054              30, Financials
#
#                              SuperSector  \
# 0               4050, Travel and Leisure
# 1                        5520, Chemicals
# 2    5020, Industrial Goods and Services
# 3                  5510, Basic Resources
# 4                        3030, Insurance
# ..                                   ...
# 185          4010, Automobiles and Parts
# 186                     1010, Technology
# 187             1510, Telecommunications
# 189                      6510, Utilities
# 191                      3030, Insurance
#
#                                            Sector  \
# 0                      405010, Travel and Leisure
# 1                               552010, Chemicals
# 2                   502010, Aerospace and Defense
# 3            551020, Industrial Metals and Mining
# 4                      303020, Non-life Insurance
# ..                                            ...
# 185                 401010, Automobiles and Parts
# 186     101020, Technology Hardware and Equipment
# 187  151020, Telecommunications Service Providers
# 189                           651010, Electricity
# 191                    303020, Non-life Insurance
#
#                                  Subsector  ...  Number of board members  \
# 0              40501025, Hotels and Motels  ...                     13.0
# 1            55201020, Specialty Chemicals  ...                     14.0
# 2                      50201010, Aerospace  ...                     12.0
# 3                 55102010, Iron and Steel  ...                     10.0
# 4            30302010, Full Line Insurance  ...                     16.0
# ..                                     ...  ...                      ...
# 185                  40101020, Automobiles  ...                     11.0
# 186               10102010, Semiconductors  ...                      9.0
# 187  15102015, Telecommunications Services  ...                     15.0
# 189     65101015, Conventional Electricity  ...                     13.0
# 191          30302010, Full Line Insurance  ...                     15.0
#
#      Market Cap in USD  \
# 0         1.033192e+10
# 1         1.051361e+11
# 2         1.361650e+11
# 3         2.175417e+10
# 4         8.254087e+10
# ..                 ...
# 185       8.246704e+10
# 186       3.663359e+10
# 187       3.591990e+09
# 189       1.562735e+10
# 191       6.241310e+09
#
#      Carbon footprint (total GHG emissions / enterprise value)_in_USD  \
# 0                                           572.631900
# 1                                                  NaN
# 2                                                  NaN
# 3                                          3373.201000
# 4                                             2.717800
# ..                                                 ...
# 185                                        6858.244394
# 186                                          27.984900
# 187                                         133.632300
# 189                                         141.369684
# 191                                         509.708945
#
#      Share of women in total workforce in %  \
# 0                                       NaN
# 1                                     0.280
# 2                                     0.200
# 3                                       NaN
# 4                                       NaN
# ..                                      ...
# 185                                     NaN
# 186                                     NaN
# 187                                   0.380
# 189                                   0.161
# 191                                   0.543
#
#      Share of women in management bodies in %  Gender pay gap in %  \
# 0                                         NaN                  NaN
# 1                                       0.300                  NaN
# 2                                         NaN                  NaN
# 3                                       0.157                  NaN
# 4                                       0.353                  NaN
# ..                                        ...                  ...
# 185                                       NaN                  NaN
# 186                                       NaN                  NaN
# 187                                     0.280                  NaN
# 189                                     0.237                 0.19
# 191                                     0.162                 0.09
#
#      Rate of employees with disabilities in %  \
# 0                                         NaN
# 1                                       0.045
# 2                                         NaN
# 3                                         NaN
# 4                                       0.007
# ..                                        ...
# 185                                       NaN
# 186                                       NaN
# 187                                     0.030
# 189                                       NaN
# 191                                       NaN
#
#      Board gender diversity (female board members / total board members) in %  \
# 0                                                0.615
# 1                                                0.357
# 2                                                0.333
# 3                                                0.300
# 4                                                0.563
# ..                                                 ...
# 185                                              0.273
# 186                                              0.444
# 187                                              0.400
# 189                                              0.461
# 191                                              0.400
#
#      Total energy consumption in mwh  Rate of resignation in %
# 0                       1.371200e+07                       NaN
# 1                                NaN                     0.086
# 2                       3.717000e+06                       NaN
# 3                       3.866670e+08                       NaN
# 4                       2.236380e+05                     0.100
# ..                               ...                       ...
# 185                     1.549489e+07                       NaN
# 186                     2.878880e+06                       NaN
# 187                     2.671000e+06                       NaN
# 189                     2.578550e+05                     0.018
# 191                     1.474418e+05                     0.027
#
# [187 rows x 22 columns]
